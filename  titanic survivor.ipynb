# %%
import numpy as np
import pandas as pd

# %%
 df = pd.read_csv('titanic-passengers.csv', sep=';')
 df.head(20)
# Out:
#     PassengerId Survived  Pclass  \
# 0           343       No       2
# 1            76       No       3
# 2           641       No       3
# 3           568       No       3
# 4           672       No       1
# 5           105       No       3
# 6           576       No       3
# 7           382      Yes       3
# 8           228       No       3
# 9           433      Yes       2
# 10          135       No       2
# 11          294       No       3
# 12          755      Yes       2
# 13          595       No       2
# 14          127       No       3
# 15          434       No       3
# 16          378       No       1
# 17          533       No       3
# 18          666       No       2
# 19          225      Yes       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                          Collander, Mr. Erik Gustaf    male  28.0      0
# 1                             Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                              Jensen, Mr. Hans Peder    male  20.0      0
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                              Davidson, Mr. Thornton    male  31.0      1
# 5                      Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                                Patchett, Mr. George    male  19.0      0
# 7                         Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                     Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
# 10                     Sobey, Mr. Samuel James Hayden    male  25.0      0
# 11                                Haas, Miss. Aloisia  female  24.0      0
# 12                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 13                            Chapman, Mr. John Henry    male  37.0      1
# 14                                McMahon, Mr. Martin    male   NaN      0
# 15                         Kallio, Mr. Nikolai Erland    male  17.0      0
# 16                          Widener, Mr. Harry Elkins    male  27.0      0
# 17                               Elias, Mr. Joseph Jr    male  17.0      1
# 18                                 Hickman, Mr. Lewis    male  32.0      2
# 19                       Hoyt, Mr. Frederick Maxfield    male  38.0      1
#
#     Parch             Ticket      Fare  Cabin Embarked
# 0       0             248740   13.0000    NaN        S
# 1       0             348123    7.6500  F G73        S
# 2       0             350050    7.8542    NaN        S
# 3       4             349909   21.0750    NaN        S
# 4       0         F.C. 12750   52.0000    B71        S
# 5       0            3101276    7.9250    NaN        S
# 6       0             358585   14.5000    NaN        S
# 7       2               2653   15.7417    NaN        C
# 8       0          A/5 21173    7.2500    NaN        S
# 9       0         SC/AH 3085   26.0000    NaN        S
# 10      0         C.A. 29178   13.0000    NaN        S
# 11      0             349236    8.8500    NaN        S
# 12      2             220845   65.0000    NaN        S
# 13      0        SC/AH 29037   26.0000    NaN        S
# 14      0             370372    7.7500    NaN        Q
# 15      0  STON/O 2. 3101274    7.1250    NaN        S
# 16      2             113503  211.5000    C82        C
# 17      1               2690    7.2292    NaN        C
# 18      0       S.O.C. 14879   73.5000    NaN        S
# 19      0              19943   90.0000    C93        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False   True  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False   True     False
# 4    False  False     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False   True     False
# 888  False   True     False
# 889  False   True     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Number of missing values in Age 
df['Age'].isnull().sum()
# Out:
# 177

# %%
#Number of missing values in Cabin
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
#Number of missing values in Emabarked
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
import numpy as np
#we selesct numeric colums in the dataframe
numeric = df.select_dtypes (include=np.number)
numeruc_columns = numeric.columns

# %%
#print the numeric columns
numeric
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare
# 0            343       2  28.0      0      0  13.0000
# 1             76       3  25.0      0      0   7.6500
# 2            641       3  20.0      0      0   7.8542
# 3            568       3  29.0      0      4  21.0750
# 4            672       1  31.0      1      0  52.0000
# ..           ...     ...   ...    ...    ...      ...
# 886           10       2  14.0      1      0  30.0708
# 887           61       3  22.0      0      0   7.2292
# 888          535       3  30.0      0      0   8.6625
# 889          102       3   NaN      0      0   7.8958
# 890          428       2  19.0      0      0  26.0000
#
# [891 rows x 6 columns]

# %%
#we fill the NaN values of numeric columns with the average value
df['Age'].fillna(df['Age'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df= df.fillna(df.mode().iloc[0])
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare    Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000  B96 B98        S
# 1    male  25.0      0      0      348123   7.6500    F G73        S
# 2    male  20.0      0      0      350050   7.8542  B96 B98        S
# 3  female  29.0      0      4      349909  21.0750  B96 B98        S
# 4    male  31.0      1      0  F.C. 12750  52.0000      B71        S

# %%
#number of missing values
df.drop('Cabin', axis=1, inplace=True)

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
 #drop the rows where at least one element is missing
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
 #We will create a new feature (column) called family_size by combining ‘SibSp’(Sibling & Spouse) and ‘Parch’(Parent & Children).
def create_fam_size(df):
    return df["SibSp"] + df["Parch"] + 1

df["family_size"] = create_fam_size(df)

# %%
import re
def create_categorical_title(df):
    def find_title(name: str) -> str:
        search = re.search(
            " ([A-Za-z]+)\.", name
        )  # Search for a word with a point at the end
        if search:
            title = search.group(1)
            if title in ["Mlle", "Ms"]:
                return "Miss"
            elif title in ["Mme", "Mrs"]:
                return "Mrs"
            elif title == "Mr":
                return "Mr"
            else:
                return "Rare"
        return ""

    return_title = df["Name"].apply(find_title)
    dict_title = {"Miss": 1, "Mrs": 2, "Mr": 3, "Rare": 4}
    return return_title.replace(dict_title)


df["Title"] = create_categorical_title(df)

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Embarked  family_size  \
# 0    male  28.0      0      0      248740  13.0000        S            1
# 1    male  25.0      0      0      348123   7.6500        S            1
# 2    male  20.0      0      0      350050   7.8542        S            1
# 3  female  29.0      0      4      349909  21.0750        S            5
# 4    male  31.0      1      0  F.C. 12750  52.0000        S            2
#
#    Title
# 0      3
# 1      3
# 2      3
# 3      2
# 4      3

# %%
def titanic_children(passenger):
    
    age , sex = passenger
    if age <16:
        return 'child'
    else:
        return sex
df['person'] = df[['Age','Sex']].apply(titanic_children,axis=1)
df["person"].value_counts() #Get a number of male and female
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
 df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Embarked  family_size  \
# 0    male  28.0      0      0      248740  13.0000        S            1
# 1    male  25.0      0      0      348123   7.6500        S            1
# 2    male  20.0      0      0      350050   7.8542        S            1
# 3  female  29.0      0      4      349909  21.0750        S            5
# 4    male  31.0      1      0  F.C. 12750  52.0000        S            2
#
#    Title  person
# 0      3    male
# 1      3    male
# 2      3    male
# 3      2  female
# 4      3    male

# %%
df['Alone'] = df.family_size

# %%
# if Alone value is >0 then they are with family else they are Alone


df['Alone'].loc[df['Alone']>0] = 'With Family'
df['Alone'].loc[df['Alone'] == 0] = 'Without Family'
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
 df.head(15)
# Out:
#     PassengerId Survived  Pclass  \
# 0           343       No       2
# 1            76       No       3
# 2           641       No       3
# 3           568       No       3
# 4           672       No       1
# 5           105       No       3
# 6           576       No       3
# 7           382      Yes       3
# 8           228       No       3
# 9           433      Yes       2
# 10          135       No       2
# 11          294       No       3
# 12          755      Yes       2
# 13          595       No       2
# 14          127       No       3
#
#                                                  Name     Sex        Age  \
# 0                          Collander, Mr. Erik Gustaf    male  28.000000
# 1                             Moen, Mr. Sigurd Hansen    male  25.000000
# 2                              Jensen, Mr. Hans Peder    male  20.000000
# 3         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                              Davidson, Mr. Thornton    male  31.000000
# 5                      Gustafsson, Mr. Anders Vilhelm    male  37.000000
# 6                                Patchett, Mr. George    male  19.000000
# 7                         Nakid, Miss. Maria ("Mary")  female   1.000000
# 8                     Lovell, Mr. John Hall ("Henry")    male  20.500000
# 9   Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.000000
# 10                     Sobey, Mr. Samuel James Hayden    male  25.000000
# 11                                Haas, Miss. Aloisia  female  24.000000
# 12                   Herman, Mrs. Samuel (Jane Laver)  female  48.000000
# 13                            Chapman, Mr. John Henry    male  37.000000
# 14                                McMahon, Mr. Martin    male  29.699118
#
#     SibSp  Parch       Ticket     Fare Embarked  family_size  Title  person  \
# 0       0      0       248740  13.0000        S            1      3    male
# 1       0      0       348123   7.6500        S            1      3    male
# 2       0      0       350050   7.8542        S            1      3    male
# 3       0      4       349909  21.0750        S            5      2  female
# 4       1      0   F.C. 12750  52.0000        S            2      3    male
# 5       2      0      3101276   7.9250        S            3      3    male
# 6       0      0       358585  14.5000        S            1      3    male
# 7       0      2         2653  15.7417        C            3      4   child
# 8       0      0    A/5 21173   7.2500        S            1      3    male
# 9       1      0   SC/AH 3085  26.0000        S            2      2  female
# 10      0      0   C.A. 29178  13.0000        S            1      3    male
# 11      0      0       349236   8.8500        S            1      4  female
# 12      1      2       220845  65.0000        S            4      2  female
# 13      1      0  SC/AH 29037  26.0000        S            2      3    male
# 14      0      0       370372   7.7500        Q            1      3    male
#
#           Alone
# 0   With Family
# 1   With Family
# 2   With Family
# 3   With Family
# 4   With Family
# 5   With Family
# 6   With Family
# 7   With Family
# 8   With Family
# 9   With Family
# 10  With Family
# 11  With Family
# 12  With Family
# 13  With Family
# 14  With Family

# %%
df["Survived"].value_counts() #Get a number of who is Survived or not
# Out:
# No     549
# Yes    342
# Name: Survived, dtype: int64

# %%
cleanup_Survived = {"Survived":{"No": 0, "Yes": 1}}

# %%
df = df.replace(cleanup_Survived) #replace Yes & No with 0 & 1
df.head(10) #print the 1st 5 rows of the data frame
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare Embarked  family_size  Title  person  \
# 0      0      248740  13.0000        S            1      3    male
# 1      0      348123   7.6500        S            1      3    male
# 2      0      350050   7.8542        S            1      3    male
# 3      4      349909  21.0750        S            5      2  female
# 4      0  F.C. 12750  52.0000        S            2      3    male
# 5      0     3101276   7.9250        S            3      3    male
# 6      0      358585  14.5000        S            1      3    male
# 7      2        2653  15.7417        C            3      4   child
# 8      0   A/5 21173   7.2500        S            1      3    male
# 9      0  SC/AH 3085  26.0000        S            2      2  female
#
#          Alone
# 0  With Family
# 1  With Family
# 2  With Family
# 3  With Family
# 4  With Family
# 5  With Family
# 6  With Family
# 7  With Family
# 8  With Family
# 9  With Family

# %%
df["person"].value_counts() #Get a number of male and female
# Out:
# male      537
# female    271
# child      83
# Name: person, dtype: int64

# %%
cleanup_Sex = {"person":     {"female": 0, "male": 1 , "child": 3}}

# %%
df = df.replace(cleanup_Sex)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare Embarked  family_size  Title  person  \
# 0      0      248740  13.0000        S            1      3       1
# 1      0      348123   7.6500        S            1      3       1
# 2      0      350050   7.8542        S            1      3       1
# 3      4      349909  21.0750        S            5      2       0
# 4      0  F.C. 12750  52.0000        S            2      3       1
# 5      0     3101276   7.9250        S            3      3       1
# 6      0      358585  14.5000        S            1      3       1
# 7      2        2653  15.7417        C            3      4       3
# 8      0   A/5 21173   7.2500        S            1      3       1
# 9      0  SC/AH 3085  26.0000        S            2      2       0
#
#          Alone
# 0  With Family
# 1  With Family
# 2  With Family
# 3  With Family
# 4  With Family
# 5  With Family
# 6  With Family
# 7  With Family
# 8  With Family
# 9  With Family

# %%
df["Embarked"].value_counts() #
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
cleanup_Embarked = {"Embarked"      :{"S": 1,"C":2, "Q": 3}}

# %%
df = df.replace(cleanup_Embarked)   
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Embarked  family_size  Title  person  \
# 0      0      248740  13.0000         1            1      3       1
# 1      0      348123   7.6500         1            1      3       1
# 2      0      350050   7.8542         1            1      3       1
# 3      4      349909  21.0750         1            5      2       0
# 4      0  F.C. 12750  52.0000         1            2      3       1
# 5      0     3101276   7.9250         1            3      3       1
# 6      0      358585  14.5000         1            1      3       1
# 7      2        2653  15.7417         2            3      4       3
# 8      0   A/5 21173   7.2500         1            1      3       1
# 9      0  SC/AH 3085  26.0000         1            2      2       0
#
#          Alone
# 0  With Family
# 1  With Family
# 2  With Family
# 3  With Family
# 4  With Family
# 5  With Family
# 6  With Family
# 7  With Family
# 8  With Family
# 9  With Family

# %%
df["Alone"].value_counts()
# Out:
# With Family    891
# Name: Alone, dtype: int64

# %%
cleanup_Alone = {"Alone":     {"With Family": 1, "Alone": 0}}

# %%
df = df.replace(cleanup_Alone)
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          343         0       2
# 1           76         0       3
# 2          641         0       3
# 3          568         0       3
# 4          672         0       1
# 5          105         0       3
# 6          576         0       3
# 7          382         1       3
# 8          228         0       3
# 9          433         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                         Collander, Mr. Erik Gustaf    male  28.0      0
# 1                            Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                             Jensen, Mr. Hans Peder    male  20.0      0
# 3        Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                             Davidson, Mr. Thornton    male  31.0      1
# 5                     Gustafsson, Mr. Anders Vilhelm    male  37.0      2
# 6                               Patchett, Mr. George    male  19.0      0
# 7                        Nakid, Miss. Maria ("Mary")  female   1.0      0
# 8                    Lovell, Mr. John Hall ("Henry")    male  20.5      0
# 9  Louch, Mrs. Charles Alexander (Alice Adelaide ...  female  42.0      1
#
#    Parch      Ticket     Fare  Embarked  family_size  Title  person  Alone
# 0      0      248740  13.0000         1            1      3       1      1
# 1      0      348123   7.6500         1            1      3       1      1
# 2      0      350050   7.8542         1            1      3       1      1
# 3      4      349909  21.0750         1            5      2       0      1
# 4      0  F.C. 12750  52.0000         1            2      3       1      1
# 5      0     3101276   7.9250         1            3      3       1      1
# 6      0      358585  14.5000         1            1      3       1      1
# 7      2        2653  15.7417         2            3      4       3      1
# 8      0   A/5 21173   7.2500         1            1      3       1      1
# 9      0  SC/AH 3085  26.0000         1            2      2       0      1

# %%
df['Alone'] = df.SibSp + df.Parch

# %%
df.drop('Name', axis=1, inplace=True)

# %%
df.drop('Ticket', axis=1, inplace=True)

# %%
df.drop('Fare', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Embarked     891 non-null    int64
#  8   family_size  891 non-null    int64
#  9   Title        891 non-null    int64
#  10  person       891 non-null    int64
#  11  Alone        891 non-null    int64
# dtypes: float64(1), int64(10), object(1)
# memory usage: 90.5+ KB

# %%
sns.factorplot('Sex',data=df,kind='count')

sns.factorplot('Pclass',data=df,kind='count')
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.factorplot('Pclass',data=df,hue='Sex',kind='count')
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Pclass',data=df,hue='person',kind='count')
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Pclass',data=df,kind='count')
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Alone',data=df,kind='count')
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.factorplot('Pclass',data=df,hue='Alone',kind='count')
# Out:
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Nouf\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Age'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df['SibSp'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
df['Parch'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="darkgrid")

# %%
sns.displot(
    df, x="Age", col="Survived", row="Sex",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

penguins = sns.load_dataset("penguins")

# Draw a nested barplot by species and sex
g = sns.catplot(
    data=penguins, kind="bar",
    x="species", y="body_mass_g", hue="sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Body mass (g)")
g.legend.set_title("")

# %%
import matplotlib.pyplot as plt
import numpy as np

ages=[1, 1, 1, 2, 2, 2, 2, 2, 2, 30, 30, 30, 150, 152]

plt.hist(ages, edgecolor='black')

plt.title("Scores vs. Frequency")
plt.xlabel("Score")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
par(mfrow=c(3, 2))
set.seed(1776)
w = rlnorm(100, 100, 20)
 hist(w, prob=T, col="wheat")
 hist(log10(w), prob=T, col="skyblue2")
x = rgamma(100, 2, .01)
 hist(x, prob=T, col="wheat")
  hist(log10(x), prob=T, col="skyblue2")
y = rweibull(100, 1, 100)
 hist(y, prob=T, col="wheat")
  hist(log10(y), prob=T, col="skyblue2")
par(mfrow=c(1,1))
# Out:
#   File "C:\Users\Nouf\AppData\Local\Temp/ipykernel_18220/2837781715.py", line 4
#     hist(w, prob=T, col="wheat")
#     ^
# IndentationError: unexpected indent
